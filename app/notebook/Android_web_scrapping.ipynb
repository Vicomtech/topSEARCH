# %%
from google_play_scraper import search
import json

# %%
result = search("breast cancer")  # defaults to 30 (= Google's maximum)

print(json.dumps(result, indent=2))
print(len(json.dumps(result, indent=2)))
# Out:
# [
#   {
#     "appId": "com.healthline.breastcancer",
#     "icon": "https://play-lh.googleusercontent.com/lFzxPHdD9kjtCqZxV60IrdgNnQdt5eUWdF45IbQhMUcGVci1owLJ8FGa_Mx-wFzKJvk",
#     "screenshots": [
#       "https://play-lh.googleusercontent.com/dy-VCAIKVLojcGPCRuqRbpz37N9PTdYXsrsX3PNUoWTjiHYoLPNcRIkWOkVcn2zjG8Q",
#       "https://play-lh.googleusercontent.com/rEVUSmAP9qVrQXtHsWp3Gvvd8Y4fjSyElf2I9RwzaaelXdIOjb8ePAXOyGSDRBOe-_E",
#       "https://play-lh.googleusercontent.com/yzGevYXhyWVlCGt8gNjuAI-5OQULyDbVq-5MyJYhfpQpcgaJaDOBoRX4b-l5BfVQ0w",
#       "https://play-lh.googleusercontent.com/pSVmODIMxrWmRMdXaOS2kWRhRnpLLzyrtIXyLjfrELCbYbVgu-_A01URGgCail8qiw",
#       "https://play-lh.googleusercontent.com/bDquhHGV9qikYe-L4EXgD58qLlcBO2BKXINVC_AKABRl8hViKwe6rbk5YTJD2U3NCnk",
#       "https://play-lh.googleusercontent.com/PZTlZqxeRhWbJ9uCnrxmVMrmByY58zdpoD1oRyFQG52bB7LaszoczpmulqNUesKpKbg"
#     ],
#     "title": "Bezzy Breast Cancer",
#     "score": 4.59,
# ...

# %%
from google_play_scraper import app

result = app('com.mobeasyapp.app665380870089', lang='it')
print(result)
# Out:
# {'title': 'Breast cancer', 'description': 'Breast cancer\r\nLearn more about everything about breast cancer through our application that provides scientific facts\r\nEarly detection of breast cancer is of great importance in treatment.  This information and many more about everything that interests you in this topic, we put it in your hands in this application in the form of scientific facts in a simplified and easy to understand manner', 'descriptionHTML': 'Breast cancer<br>Learn more about everything about breast cancer through our application that provides scientific facts<br>Early detection of breast cancer is of great importance in treatment.  This information and many more about everything that interests you in this topic, we put it in your hands in this application in the form of scientific facts in a simplified and easy to understand manner', 'summary': 'Breast cancer app', 'installs': '10+', 'minInstalls': 10, 'realInstalls': 20, 'score': 0, 'ratings': 0, 'reviews': 0, 'hist
# ...
